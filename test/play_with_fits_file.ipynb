# %%
# import some package
import numpy as np

import matplotlib.pyplot as plt

# open what is needed to open fits files
from astropy.io import fits

# %%
fits_file="HorseHead.fits"
fits_hdu = fits.open(fits_file)

# %%
print(fits_hdu)
# Out:
# [<astropy.io.fits.hdu.image.PrimaryHDU object at 0x10d2466f0>, <astropy.io.fits.hdu.table.TableHDU object at 0x10d494b90>]

# %%
fits_hdu.info()
# Out:
# Filename: HorseHead.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     161   (891, 893)   int16
#   1  er.mask       1 TableHDU        25   1600R x 4C   [F6.2, F6.2, F6.2, F6.2]

# %%
data = fits_hdu[0].data

# %%
cb = plt.imshow(data, cmap='inferno')
plt.colorbar(cb)
plt.xlabel("x")
plt.ylabel("y")
# Out:
# Text(0, 0.5, 'y')
