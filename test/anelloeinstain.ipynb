# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
import sys
sys.path.append('../')
from pyACC.fits import FitsManager

# %%
fits_file="anelloeinstein.fits"
fits_hdu = fits.open(fits_file)

# %%
plt.plot(fits_hdu[0].data)
plt.xlabel('Pixel')
plt.ylabel('Intensity')
plt.show()

# %%
data = fits_hdu[0].data
cb = plt.imshow(data, cmap='twilight')
plt.colorbar(cb)
plt.xlabel("x")
plt.ylabel("y")
# Out:
# Text(0, 0.5, 'y')
